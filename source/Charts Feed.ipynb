# %%
import os
import boto3

from botocore.exceptions import ClientError
from boto3.dynamodb.conditions import Key, Attr

TABLE_NAME="weekly"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Do not hard code credentials
dynamodb = boto3.client(
    'dynamodb',
    # Hard coded strings as credentials, not recommended.
    region_name = 'us-west-2',
    aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
    aws_secret_access_key=os.getenv('AWS_SECRET_ACCESS_KEY')
)
table = dynamodb.describe_table(TableName=TABLE_NAME)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_charts_by_country(country):
    response = dynamodb.query(TableName=TABLE_NAME,
                              KeyConditionExpression='country = :country',
                              ExpressionAttributeValues={':country': {'S': country}})
    data = response["Items"]
    while 'LastEvaluatedKey' in response:
        response = dynamodb.query(TableName=TABLE_NAME,
                                  ExclusiveStartKey=response['LastEvaluatedKey'],
                                  KeyConditionExpression='country = :country',
                                  ExpressionAttributeValues={':country': {'S': country}})
        data.extend(response['Items'])
    return data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_chart_by_id(country, day):
    try:
        response = dynamodb.get_item(
            TableName=TABLE_NAME,      
            Key={'country': {'S': country},'day': {'S': day}}
        )
    except ClientError as e:
        print(e.response['Error']['Message'])
    return response['Item']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def get_all_charts():
    response = dynamodb.scan(TableName=TABLE_NAME)
    data = response["Items"]
    while 'LastEvaluatedKey' in response:
        response = dynamodb.scan(TableName=TABLE_NAME,
                                  ExclusiveStartKey=response['LastEvaluatedKey'])
        data.extend(response['Items'])
    return data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
chart = get_chart_by_id('global', '2018-09-27')
chart
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: {&#39;songs&#39;: {&#39;L&#39;: [{&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;1&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;33921412&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4S8d14HvHb70ImctNgVzQQ&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;2&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;32511658&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0Dn40gxVCMo5TkgS8Ik18Q&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;3&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;24222554&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;2dpaYNEQHiRxtZbfNsse99&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;4&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;22304777&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;2G7V7zsVDxg1yRsu7Ew9RJ&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;5&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;22293206&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0d2iYfpKoM0QCKvcLCkBao&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;6&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;21838886&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5N5k9nd479b1xpDZ4usjrg&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;7&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;21515150&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0E9ZjEAyAwOXZ7wJC0PD33&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;8&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;21396072&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;60SdxE8apGAxMiRrpbmLY0&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;9&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;18879687&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0s3nnoMeVWz3989MkNQiRf&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;10&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;18709601&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;2xLMifQCjDGFmkHkpNLD9h&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;11&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;17296395&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;7fa9MBXhVfQ8P8Df9OEbD8&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;12&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;17251714&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4T3fNx3CgwDRRYgmFCbD4J&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;13&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;17127554&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;2E124GmJRnBJuXbTb4cPUB&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;14&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;16717631&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;3EPXxR3ImUwfayaurPi3cm&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;15&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;15870224&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5N4erncE7kuUccm7zEmwzk&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;16&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;15723393&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;3ee8Jmje8o58CHK66QrVC2&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;17&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;15026546&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;7ATATJztoWLcqDAcVVof0C&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;18&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;14723927&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;48zFZh27QU5qsrBjn4C2FA&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;19&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;14480000&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5IaHrVsrferBYDm0bDyABy&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;20&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;14444816&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;58q2HKrzhC3ozto2nDdN4z&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;21&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;13827723&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4zIO3ilp5HvTeK3HJHxhMP&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;22&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;13807793&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5WvAo7DNuPRmk4APhdPzi8&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;23&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;13711262&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;1jo3TwNGCXfNdB5uba3ZVv&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;24&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;13571555&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;7dt6x5M1jzdTEt8oCbisTK&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;25&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;13518892&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0Fpen1PTuEnCmOJtUU9Iud&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;26&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;12711963&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4OafepJy2teCjYJbvFE60J&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;27&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;12483696&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0QIjsbm2fh1cJ45XO9eGqq&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;28&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;12175920&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5OCJzvD7sykQEKHH7qAC3C&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;29&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;12067632&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0JP9xo3adEtGSdUEISiszL&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;30&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;12053971&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;6kPJZM97LwdG9QIsT7khp6&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;31&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11956382&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;2iUXsYOEPhVqEBwsqP70rE&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;32&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11917880&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;3V8UKqhEK5zBkBb6d6ub8i&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;33&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11813473&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;0TlLq3lA83rQOYtrqBqSct&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;34&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11660275&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;3u1S1OmAUhx5DRlLrXqyp3&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;35&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11449385&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;5a8RPWgKSmcGBGcffmIrUi&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;36&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11380668&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;04MLEeAMuV9IlHEsD8vF6A&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;37&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;11337861&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4VUwkH455At9kENOfzTqmF&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;38&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;10950679&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;3QybPutx0Tjk472bBKjNWn&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;39&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;10948742&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;7K7MUBCnzgBAvMVW2RTWNs&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;40&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;10742144&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4kWO6O1BUXcZmaxitpVUwp&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;41&#39;},
#      &#39;s&#39;: {&#39;N&#39;: &#39;10625562&#39;},
#      &#39;id&#39;: {&#39;S&#39;: &#39;4ofwffwvvnbSkrMSCKQDaC&#39;}}},
#    {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;42&#39

# %%
charts = get_charts_by_country("global")
print(len(charts))
charts
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ask for a second page
# 175
# Out[12]: [{&#39;songs&#39;: {&#39;L&#39;: [{&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;1&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;25286465&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;5aAx2yezTd8zXrkmtKl66Z&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;2&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;22047697&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;7BKLCZ1jbUBVqRi2FVlTVw&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;3&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;19794482&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;5knuzwU65gJK7IF5yJsuaW&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;4&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;17965723&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4pdPtRcBmOSQDlJ3Fk945m&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;5&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;16966668&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;5MFzQMkrl1FOOng9tq6R9r&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;6&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;16831609&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6fujklziTHa8uoM5OQSfIo&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;7&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;16797090&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;3NdDpSvN911VPGivFlV5d0&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;8&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;16629189&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;343YBumqHu19cGoGARUTsd&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;9&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;16023066&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6b8Be6ljOzmkOmFslEb23P&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;10&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;15571413&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;5uCax9HTNlzGybIStD3vDh&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;11&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;15094760&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;0bYg9bo50gSsH3LtXe2SQn&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;12&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;14845976&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;5GXAXm5YOmYT0kL5jHvYBt&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;13&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;13620191&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;1xznGGDReH1oQq0xzbwXa3&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;14&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;13143341&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6DNtNfH8hXkqOX1sjqmI7p&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;15&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;13074479&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6bLopGnirdrilrpdVB6Um1&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;16&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;12854288&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;04DwTuZ2VBdJCCC5TROn7L&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;17&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;12309223&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;78rIJddV4X0HkNAInEcYde&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;18&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;12104974&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6mICuAdrwEjh6Y6lroV2Kg&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;19&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;11964458&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4pLwZjInHj3SimIyN9SnOz&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;20&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;11735194&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;3EmmCZoqpWOTY1g2GBwJoR&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;21&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;11724752&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;2FRnf9qhLbvw8fu4IBXx78&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;22&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10932500&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;1qOLh0tI7trd1zdDKxYZTe&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;23&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10635390&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4Km5HrUvYTaSUfiSGPJeQR&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;24&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10620238&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;1PSBzsahR2AKwLJgx8ehBj&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;25&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10507024&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4TZy1wLyHec06pwgFYDh1a&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;26&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10330481&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;1vvNmPOiUuyCbgWmtc6yfm&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;27&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10169963&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6i0V12jOa3mr6uu4WYhUBr&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;28&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;10163696&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;2rizacJSyD9S1IQUxUxnsK&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;29&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;9267559&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;0QsvXIfqM0zZoerQfsI9lm&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;30&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;9168864&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4Hf7WnR761jpxPr5D46Bcd&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;31&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;8583889&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;0prNGof3XqfTvNDxHonvdK&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;32&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;8223181&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;3AEZUABDXNtecAOSC1qTfo&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;33&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;8203210&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6nxQdXa1uAL0rY72wPZu89&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;34&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7749405&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;4b4KcovePX8Ke2cLIQTLM0&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;35&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7734734&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;6JV2JOEocMgcZxYSZelKcc&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;36&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7724332&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;08WPvDEsHvTFuB9w8tC2OS&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;37&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7669735&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;7aV2mflaASUmGhCErm7kBO&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;38&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7669293&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;1D3ODoXHBLpdxolZRHWV1j&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;39&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7596658&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;68EMU2RD1ECNeOeJ5qAXCV&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;40&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7584237&#39;},
#       &#39;id&#39;: {&#39;S&#39;: &#39;0JiVRyTJcJnmlwCZ854K4p&#39;}}},
#     {&#39;M&#39;: {&#39;pos&#39;: {&#39;N&#39;: &#39;41&#39;},
#       &#39;s&#39;: {&#39;N&#39;: &#39;7493998

# %%
all_charts = get_all_charts()
print(len(all_charts))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10603
# </div>

# %%
def remove_datatype_chart(item):
  return {'country': item['country']['S'], 'day': item['day']['S'], 'songs': [{'pos': i['M']['pos']['N'],'id': i['M']['id']['S'],'st': i['M']['s']['N']} for i in item['songs']['L']]}

charts = [remove_datatype_chart(c) for c in all_charts]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql import Row
from collections import OrderedDict

def convert_to_row(d: dict) -> Row:
    return Row(**OrderedDict(sorted(d.items())))

charts_df = sc.parallelize(charts).toDF()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/sql/session.py:375: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead
#   warnings.warn(&#34;Using RDD of dict to inferSchema is deprecated. &#34;
# </div>

# %%
charts_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+--------------------+
# country|       day|               songs|
# +-------+----------+--------------------+
#      hu|2016-12-29|[[st -&gt; 54323, id...|
#      hu|2017-01-05|[[st -&gt; 61664, id...|
#      hu|2017-01-12|[[st -&gt; 124015, i...|
#      hu|2017-01-19|[[st -&gt; 125521, i...|
#      hu|2017-01-26|[[st -&gt; 124542, i...|
#      hu|2017-02-02|[[st -&gt; 130596, i...|
#      hu|2017-02-09|[[st -&gt; 137003, i...|
#      hu|2017-02-16|[[st -&gt; 140749, i...|
#      hu|2017-02-23|[[st -&gt; 137518, i...|
#      hu|2017-03-02|[[st -&gt; 134185, i...|
#      hu|2017-03-09|[[st -&gt; 149747, i...|
#      hu|2017-03-16|[[st -&gt; 133634, i...|
#      hu|2017-03-23|[[st -&gt; 121459, i...|
#      hu|2017-03-30|[[st -&gt; 113024, i...|
#      hu|2017-04-06|[[st -&gt; 100901, i...|
#      hu|2017-04-13|[[st -&gt; 98435, id...|
#      hu|2017-04-20|[[st -&gt; 81832, id...|
#      hu|2017-04-27|[[st -&gt; 82594, id...|
#      hu|2017-05-04|[[st -&gt; 81766, id...|
#      hu|2017-05-11|[[st -&gt; 86903, id...|
# +-------+----------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
charts_df.write.format("json").saveAsTable("weekly_charts_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
country_df = charts_df.groupBy("country").count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
country_df.show(n=63, truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# country|count|
# +-------+-----+
# cr     |175  |
# us     |175  |
# il     |114  |
# cl     |175  |
# ro     |114  |
# jp     |141  |
# lv     |175  |
# vn     |114  |
# pl     |175  |
# za     |114  |
# sk     |175  |
# pt     |175  |
# in     |64   |
# ni     |175  |
# au     |175  |
# sg     |175  |
# hk     |175  |
# be     |175  |
# tw     |175  |
# gb     |175  |
# ec     |175  |
# co     |175  |
# tr     |175  |
# is     |175  |
# lu     |175  |
# de     |175  |
# global |175  |
# br     |175  |
# gt     |175  |
# es     |175  |
# uy     |175  |
# it     |175  |
# py     |175  |
# pe     |175  |
# ar     |175  |
# sv     |175  |
# ph     |175  |
# bo     |175  |
# nl     |175  |
# hn     |175  |
# hu     |175  |
# ca     |175  |
# my     |175  |
# ee     |175  |
# nz     |175  |
# mt     |175  |
# gr     |175  |
# th     |142  |
# ch     |175  |
# lt     |175  |
# do     |175  |
# pa     |175  |
# no     |175  |
# bg     |175  |
# at     |175  |
# cz     |175  |
# mx     |175  |
# fr     |175  |
# se     |175  |
# ie     |175  |
# dk     |175  |
# id     |175  |
# fi     |175  |
# +-------+-----+
#
# </div>

# %%
def get_all(table_name):
    print("Getting data from " + table_name)
    response = dynamodb.scan(TableName=table_name)
    data = response["Items"]
    while 'LastEvaluatedKey' in response:
        response = dynamodb.scan(TableName=table_name,
                                  ExclusiveStartKey=response['LastEvaluatedKey'])
        data.extend(response['Items'])
    return data
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
all_songs = get_all("songs_feature")
print(len(all_songs))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">49384
# </div>

# %%
def remove_datatype_songs(item):
  return {'acousticness': float(item['a']['S']), 
          'time_signature': int(item['ts']['S']),
          'danceability': float(item['d']['S']),
          'energy': float(item['e']['S']),
          'instrumentalness': float(item['i']['S']),
          'duration_ms': int(item['dm']['S']),
          'key': int(item['k']['S']),
          'loudness': float(item['l']['S']),
          's_id': item['s_id']['S'],
          'mode': int(item['m']['S']),
          'speechiness': float(item['s']['S']),
          'tempo': float(item['t']['S']),
          'valence': float(item['v']['S']),
          'liveness': float(item['li']['S'])}

song_features = [remove_datatype_songs(s) for s in all_songs]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
song_features
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: [{&#39;acousticness&#39;: 0.169,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.834,
#   &#39;energy&#39;: 0.685,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 376293,
#   &#39;key&#39;: 1,
#   &#39;loudness&#39;: -8.24,
#   &#39;s_id&#39;: &#39;59B7zyMX6ClvnkBeqQWQ0b&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.202,
#   &#39;tempo&#39;: 92.991,
#   &#39;valence&#39;: 0.679,
#   &#39;liveness&#39;: 0.0452},
#  {&#39;acousticness&#39;: 0.0172,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.79,
#   &#39;energy&#39;: 0.867,
#   &#39;instrumentalness&#39;: 0.00012,
#   &#39;duration_ms&#39;: 345000,
#   &#39;key&#39;: 7,
#   &#39;loudness&#39;: -5.582,
#   &#39;s_id&#39;: &#39;6bBlIcMHsXrqUrLIKbA9Dx&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0466,
#   &#39;tempo&#39;: 123.047,
#   &#39;valence&#39;: 0.893,
#   &#39;liveness&#39;: 0.0941},
#  {&#39;acousticness&#39;: 0.0696,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.668,
#   &#39;energy&#39;: 0.807,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 206316,
#   &#39;key&#39;: 9,
#   &#39;loudness&#39;: -4.681,
#   &#39;s_id&#39;: &#39;1gaK2od5J8GX6KecOaWm4d&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0612,
#   &#39;tempo&#39;: 113.896,
#   &#39;valence&#39;: 0.828,
#   &#39;liveness&#39;: 0.0625},
#  {&#39;acousticness&#39;: 0.125,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.905,
#   &#39;energy&#39;: 0.694,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 116760,
#   &#39;key&#39;: 1,
#   &#39;loudness&#39;: -5.669,
#   &#39;s_id&#39;: &#39;44fqzUIKdfrLMY9MZxEs5R&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.44,
#   &#39;tempo&#39;: 124.969,
#   &#39;valence&#39;: 0.57,
#   &#39;liveness&#39;: 0.179},
#  {&#39;acousticness&#39;: 0.31,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.718,
#   &#39;energy&#39;: 0.705,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 213257,
#   &#39;key&#39;: 0,
#   &#39;loudness&#39;: -6.975,
#   &#39;s_id&#39;: &#39;7BjX8clU1Ss1SD48St76gE&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0648,
#   &#39;tempo&#39;: 97.991,
#   &#39;valence&#39;: 0.663,
#   &#39;liveness&#39;: 0.0837},
#  {&#39;acousticness&#39;: 0.465,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.454,
#   &#39;energy&#39;: 0.853,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 152951,
#   &#39;key&#39;: 4,
#   &#39;loudness&#39;: -4.958,
#   &#39;s_id&#39;: &#39;6UIPDLuTq3tM9X4TJku6kK&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0604,
#   &#39;tempo&#39;: 137.086,
#   &#39;valence&#39;: 0.242,
#   &#39;liveness&#39;: 0.336},
#  {&#39;acousticness&#39;: 0.0944,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.793,
#   &#39;energy&#39;: 0.946,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 198268,
#   &#39;key&#39;: 0,
#   &#39;loudness&#39;: -3.141,
#   &#39;s_id&#39;: &#39;3jMimE9wZwPxVDiUgzFeDm&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0584,
#   &#39;tempo&#39;: 99.996,
#   &#39;valence&#39;: 0.742,
#   &#39;liveness&#39;: 0.145},
#  {&#39;acousticness&#39;: 4.22e-05,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.597,
#   &#39;energy&#39;: 0.911,
#   &#39;instrumentalness&#39;: 0.00137,
#   &#39;duration_ms&#39;: 214986,
#   &#39;key&#39;: 1,
#   &#39;loudness&#39;: -4.1,
#   &#39;s_id&#39;: &#39;1lgtuKQkhlOr0LySn892KY&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.0644,
#   &#39;tempo&#39;: 127.993,
#   &#39;valence&#39;: 0.314,
#   &#39;liveness&#39;: 0.096},
#  {&#39;acousticness&#39;: 0.218,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.799,
#   &#39;energy&#39;: 0.736,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 138702,
#   &#39;key&#39;: 6,
#   &#39;loudness&#39;: -5.861,
#   &#39;s_id&#39;: &#39;6RjHsYQ4JYJFHes0IZjCTV&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.153,
#   &#39;tempo&#39;: 95.01,
#   &#39;valence&#39;: 0.866,
#   &#39;liveness&#39;: 0.0772},
#  {&#39;acousticness&#39;: 0.327,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.761,
#   &#39;energy&#39;: 0.637,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 216000,
#   &#39;key&#39;: 8,
#   &#39;loudness&#39;: -7.04,
#   &#39;s_id&#39;: &#39;0uiacvQPCC2C5OdPOnyIJy&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0533,
#   &#39;tempo&#39;: 109.964,
#   &#39;valence&#39;: 0.256,
#   &#39;liveness&#39;: 0.0812},
#  {&#39;acousticness&#39;: 0.536,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.704,
#   &#39;energy&#39;: 0.545,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 358627,
#   &#39;key&#39;: 7,
#   &#39;loudness&#39;: -7.545,
#   &#39;s_id&#39;: &#39;2e9ubFSxKQtJh1MDbVzMug&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.0323,
#   &#39;tempo&#39;: 109.953,
#   &#39;valence&#39;: 0.589,
#   &#39;liveness&#39;: 0.125},
#  {&#39;acousticness&#39;: 0.354,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.647,
#   &#39;energy&#39;: 0.977,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 223794,
#   &#39;key&#39;: 0,
#   &#39;loudness&#39;: -1.692,
#   &#39;s_id&#39;: &#39;0IU0vfnWqvdfBFC5Hj8K02&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.0375,
#   &#39;tempo&#39;: 129.917,
#   &#39;valence&#39;: 0.882,
#   &#39;liveness&#39;: 0.039},
#  {&#39;acousticness&#39;: 0.103,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.579,
#   &#39;energy&#39;: 0.587,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 120551,
#   &#39;key&#39;: 9,
#   &#39;loudness&#39;: -8.383,
#   &#39;s_id&#39;: &#39;3GOZyiebYv432EnVy9XwzE&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.355,
#   &#39;tempo&#39;: 85.732,
#   &#39;valence&#39;: 0.705,
#   &#39;liveness&#39;: 0.112},
#  {&#39;acousticness&#39;: 0.0219,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.501,
#   &#39;energy&#39;: 0.757,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 173733,
#   &#39;key&#39;: 7,
#   &#39;loudness&#39;: -6.26,
#   &#39;s_id&#39;: &#39;3vRDWAfGp4qEh5ueFyyleR&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.237,
#   &#39;tempo&#39;: 84.212,
#   &#39;valence&#39;: 0.451,
#   &#39;liveness&#39;: 0.17},
#  {&#39;acousticness&#39;: 0.526,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.613,
#   &#39;energy&#39;: 0.739,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 211453,
#   &#39;key&#39;: 10,
#   &#39;loudness&#39;: -6.478,
#   &#39;s_id&#39;: &#39;6FYbr9QzRoZPh0Re8lDO9z&#39;,
#   &#39;mode&#39;: 1,
#   &#39;speechiness&#39;: 0.0311,
#   &#39;tempo&#39;: 104.966,
#   &#39;valence&#39;: 0.712,
#   &#39;liveness&#39;: 0.149},
#  {&#39;acousticness&#39;: 0.77,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.432,
#   &#39;energy&#39;: 0.405,
#   &#39;instrumentalness&#39;: 0.0,
#   &#39;duration_ms&#39;: 239907,
#   &#39;key&#39;: 11,
#   &#39;loudness&#39;: -7.978,
#   &#39;s_id&#39;: &#39;1qBNcwRLUqNyWZhHMzZj4p&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.0531,
#   &#39;tempo&#39;: 81.987,
#   &#39;valence&#39;: 0.479,
#   &#39;liveness&#39;: 0.0897},
#  {&#39;acousticness&#39;: 0.271,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.781,
#   &#39;energy&#39;: 0.541,
#   &#39;instrumentalness&#39;: 8.58e-06,
#   &#39;duration_ms&#39;: 151440,
#   &#39;key&#39;: 5,
#   &#39;loudness&#39;: -8.05,
#   &#39;s_id&#39;: &#39;2n4dgesf5weBTyhN538xT5&#39;,
#   &#39;mode&#39;: 0,
#   &#39;speechiness&#39;: 0.417,
#   &#39;tempo&#39;: 139.983,
#   &#39;valence&#39;: 0.316,
#   &#39;liveness&#39;: 0.441},
#  {&#39;acousticness&#39;: 0.745,
#   &#39;time_signature&#39;: 4,
#   &#39;danceability&#39;: 0.586,
#   &#39;energy&#39;: 0.323,
#   &#39;instrumentalness&#39;: 2.57e-06,
#   &#39;duration_ms&#39;: 242934,
#   &#39;key&#39;: 1,
#   &#39;loudness&#39;: -11.428,
#   &#39;s_id&#39;: &#39;02GtNoUv85f

# %%
song_features_df = sc.parallelize(song_features).toDF()
song_features_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+------------+-----------+------+----------------+---+--------+--------+----+--------------------+-----------+-------+--------------+-------+
# acousticness|danceability|duration_ms|energy|instrumentalness|key|liveness|loudness|mode|                s_id|speechiness|  tempo|time_signature|valence|
# +------------+------------+-----------+------+----------------+---+--------+--------+----+--------------------+-----------+-------+--------------+-------+
#        0.169|       0.834|     376293| 0.685|             0.0|  1|  0.0452|   -8.24|   1|59B7zyMX6ClvnkBeq...|      0.202| 92.991|             4|  0.679|
#       0.0172|        0.79|     345000| 0.867|          1.2E-4|  7|  0.0941|  -5.582|   0|6bBlIcMHsXrqUrLIK...|     0.0466|123.047|             4|  0.893|
#       0.0696|       0.668|     206316| 0.807|             0.0|  9|  0.0625|  -4.681|   0|1gaK2od5J8GX6KecO...|     0.0612|113.896|             4|  0.828|
#        0.125|       0.905|     116760| 0.694|             0.0|  1|   0.179|  -5.669|   1|44fqzUIKdfrLMY9MZ...|       0.44|124.969|             4|   0.57|
#         0.31|       0.718|     213257| 0.705|             0.0|  0|  0.0837|  -6.975|   0|7BjX8clU1Ss1SD48S...|     0.0648| 97.991|             4|  0.663|
#        0.465|       0.454|     152951| 0.853|             0.0|  4|   0.336|  -4.958|   0|6UIPDLuTq3tM9X4TJ...|     0.0604|137.086|             4|  0.242|
#       0.0944|       0.793|     198268| 0.946|             0.0|  0|   0.145|  -3.141|   0|3jMimE9wZwPxVDiUg...|     0.0584| 99.996|             4|  0.742|
#      4.22E-5|       0.597|     214986| 0.911|         0.00137|  1|   0.096|    -4.1|   1|1lgtuKQkhlOr0LySn...|     0.0644|127.993|             4|  0.314|
#        0.218|       0.799|     138702| 0.736|             0.0|  6|  0.0772|  -5.861|   0|6RjHsYQ4JYJFHes0I...|      0.153|  95.01|             4|  0.866|
#        0.327|       0.761|     216000| 0.637|             0.0|  8|  0.0812|   -7.04|   0|0uiacvQPCC2C5OdPO...|     0.0533|109.964|             4|  0.256|
#        0.536|       0.704|     358627| 0.545|             0.0|  7|   0.125|  -7.545|   1|2e9ubFSxKQtJh1MDb...|     0.0323|109.953|             4|  0.589|
#        0.354|       0.647|     223794| 0.977|             0.0|  0|   0.039|  -1.692|   1|0IU0vfnWqvdfBFC5H...|     0.0375|129.917|             4|  0.882|
#        0.103|       0.579|     120551| 0.587|             0.0|  9|   0.112|  -8.383|   0|3GOZyiebYv432EnVy...|      0.355| 85.732|             4|  0.705|
#       0.0219|       0.501|     173733| 0.757|             0.0|  7|    0.17|   -6.26|   1|3vRDWAfGp4qEh5ueF...|      0.237| 84.212|             4|  0.451|
#        0.526|       0.613|     211453| 0.739|             0.0| 10|   0.149|  -6.478|   1|6FYbr9QzRoZPh0Re8...|     0.0311|104.966|             4|  0.712|
#         0.77|       0.432|     239907| 0.405|             0.0| 11|  0.0897|  -7.978|   0|1qBNcwRLUqNyWZhHM...|     0.0531| 81.987|             4|  0.479|
#        0.271|       0.781|     151440| 0.541|         8.58E-6|  5|   0.441|   -8.05|   0|2n4dgesf5weBTyhN5...|      0.417|139.983|             4|  0.316|
#        0.745|       0.586|     242934| 0.323|         2.57E-6|  1|  0.0769| -11.428|   1|02GtNoUv85fOPEaCT...|     0.0262| 88.876|             4|  0.428|
#        0.449|       0.921|     175547| 0.821|             0.0|  7|   0.106|  -5.097|   1|3jMuXsnbqmxUBdkda...|     0.0506|130.023|             4|  0.962|
#        0.165|       0.681|     156036| 0.719|         8.65E-6|  8|   0.117|  -7.071|   1|5aDKZysYr35N9Y0pe...|      0.236|200.441|             4|  0.659|
# +------------+------------+-----------+------+----------------+---+--------+--------+----+--------------------+-----------+-------+--------------+-------+
# only showing top 20 rows
#
# </div>

# %%
song_features_df.write.format("json").saveAsTable("song_features_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
all_songs = get_all("artists")
print(len(all_artists))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Getting data from artists
# 47677
# </div>

# %%
def remove_datatype_artists(item):
  return {'a_id': item['a_id']['S'], 
          's_id': item['s_id']['S'],
          'artist_name': item['n']['S']}

song_artists = [remove_datatype_artists(s) for s in all_songs]
song_artists
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: [{&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;2gkQ2yVzaer5qx2NzJnHXh&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;3nYMZ5nLylkcDIy1sutpB9&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;3vESKvFu212T8QajZM2BCK&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;4LeP389CNcbrQX8ZECZlPw&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;7gX4z4gcMQIJCKkZsBELr0&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;6KEEEdAqmCL7PYOrjZCnEa&#39;,
#   &#39;s_id&#39;: &#39;7w5FDBgmLNaOIM8lXjnmI5&#39;,
#   &#39;artist_name&#39;: &#39;Sufian Suhaimi&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;0bBE6IcJmQUGBNJHb3zgbd&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;0ghsodbgTYqLEOR8I8dMac&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;10Uvn3MavopnDgYERT1Z0H&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;16V4Xfm9207E9NRaoKFWOp&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;1Mk75HVvjXMIci5ROOjvAZ&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;1ffspx5F8xtFD2psv22y8C&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;1sKyNIgQuJaQkKyZeadwHD&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;2MywGOEX576jpgaFeWAZjN&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;2S4exmZO3aVEcoxLdKhC47&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;2l9TRclGKeThGh6jV1bp2o&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;3EwZENvkTpMm0Q2l89pb3x&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;3O6kDekz7KBthklhRZdPEh&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;3WI4ywfOXaOM3wDTh3TkN6&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;3yJFqy44SX9ZLhEqxssVN9&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;44fqzUIKdfrLMY9MZxEs5R&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;67iCjNiQTC1C0ebKBHvEoh&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;6Gykl9tC7Dn1jALc1IFEd9&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;6RAl2MB2QpZT46yJNgbwyC&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;6ST2JQVXyeefKBpUxiIZe1&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;6cnwIw90HqViUFz0AsfqcO&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;438nTuoZFCZCyBl33jE9dU&#39;,
#   &#39;s_id&#39;: &#39;7zVzLFfre1MDCBfJ9IMz7s&#39;,
#   &#39;artist_name&#39;: &#39;Ashafar&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;0SsP7gCmOC9eMld6QWjB7f&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;0ZNsz4YT7wJv0XbcnKqZNF&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;1eFR6APW8u8iISvBxWw5HK&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;2TABt0nj3WNPXbka7nzwIt&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;3Z7qxYXDBfv7duOaW8GenT&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;3uht5bVvbiE54iQwtrab1e&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1osZFzamKEXNoYk7HzWbDe&#39;,
#   &#39;s_id&#39;: &#39;5l1bAjDmqj4e3nBZCqqDqs&#39;,
#   &#39;artist_name&#39;: &#39;Sunrise Avenue&#39;},
#  {&#39;a_id&#39;: &#39;1vlR56ECqMAOA2mUTcTgPV&#39;,
#   &#39;s_id&#39;: &#39;3khBTuJV9nXiNqKY1k9AXZ&#39;,
#   &#39;artist_name&#39;: &#39;Emma Bale&#39;},
#  {&#39;a_id&#39;: &#39;1vlR56ECqMAOA2mUTcTgPV&#39;,
#   &#39;s_id&#39;: &#39;6pA3kqOWAQBbAzLfQK2oiR&#39;,
#   &#39;artist_name&#39;: &#39;Emma Bale&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;03mMSLEJCPoGJwQhHpN5y0&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;1IF5UcqRO42D12vYwceOY6&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;1M4qEo4HE3PRaCOM7EXNJq&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;1ZMiCix7XSAbfAJlEZWMCp&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;1e9oZCCiX42nJl0AcqriVo&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;2IOFZdYYkFxEHVz1w34PoL&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;2plLJpUcYPFrl1sW2pMG63&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;33SNO8AaciGbNaQFkxvPrW&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;33bURv895AN4FkBvgFo2dx&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;3Dwq1oiOFys6Sxr5SslmXw&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;3jjujdWJ72nww5eGnfs2E7&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;45S5WTQEGOB1VHr1Q4FuPl&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;4B1rpPmQXwj78wk6aIGwwU&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#39;,
#   &#39;s_id&#39;: &#39;4jAIqgrPjKLTY9Gbez25Qb&#39;,
#   &#39;artist_name&#39;: &#39;Harry Styles&#39;},
#  {&#39;a_id&#39;: &#39;6KImCVD70vtIoJWnq6nGn3&#3

# %%
song_artists_df = sc.parallelize(song_artists).toDF()
song_artists_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+--------------+--------------------+
#                 a_id|   artist_name|                s_id|
# +--------------------+--------------+--------------------+
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|2gkQ2yVzaer5qx2Nz...|
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|3nYMZ5nLylkcDIy1s...|
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|3vESKvFu212T8QajZ...|
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|4LeP389CNcbrQX8ZE...|
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|7gX4z4gcMQIJCKkZs...|
# 6KEEEdAqmCL7PYOrj...|Sufian Suhaimi|7w5FDBgmLNaOIM8lX...|
# 438nTuoZFCZCyBl33...|       Ashafar|0bBE6IcJmQUGBNJHb...|
# 438nTuoZFCZCyBl33...|       Ashafar|0ghsodbgTYqLEOR8I...|
# 438nTuoZFCZCyBl33...|       Ashafar|10Uvn3MavopnDgYER...|
# 438nTuoZFCZCyBl33...|       Ashafar|16V4Xfm9207E9NRao...|
# 438nTuoZFCZCyBl33...|       Ashafar|1Mk75HVvjXMIci5RO...|
# 438nTuoZFCZCyBl33...|       Ashafar|1ffspx5F8xtFD2psv...|
# 438nTuoZFCZCyBl33...|       Ashafar|1sKyNIgQuJaQkKyZe...|
# 438nTuoZFCZCyBl33...|       Ashafar|2MywGOEX576jpgaFe...|
# 438nTuoZFCZCyBl33...|       Ashafar|2S4exmZO3aVEcoxLd...|
# 438nTuoZFCZCyBl33...|       Ashafar|2l9TRclGKeThGh6jV...|
# 438nTuoZFCZCyBl33...|       Ashafar|3EwZENvkTpMm0Q2l8...|
# 438nTuoZFCZCyBl33...|       Ashafar|3O6kDekz7KBthklhR...|
# 438nTuoZFCZCyBl33...|       Ashafar|3WI4ywfOXaOM3wDTh...|
# 438nTuoZFCZCyBl33...|       Ashafar|3yJFqy44SX9ZLhEqx...|
# +--------------------+--------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
song_artists_df.write.format("json").saveAsTable("song_artists_table")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
artists_df = song_artists_df.groupBy("artist_name").count()
artists_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-----+
#       artist_name|count|
# +-----------------+-----+
#        Snoop Dogg|    2|
#          Superfly|    3|
#         Gary Chaw|    2|
#              阿涵|    3|
#        PartyFriex|    2|
#            *NSYNC|    4|
#        Eurythmics|    1|
#       Lake Malawi|    1|
#           bonobos|    1|
#          CHUNG HA|    3|
# Gabriele Esposito|    1|
#              Reto|   14|
#    The Black Keys|    1|
#            Grimes|    1|
#      Made Of Snow|    1|
#              ANNA|    4|
#       Server Uraz|    1|
#      TangBadVoice|    3|
#          Jess Lee|    5|
#              Gedz|    9|
# +-----------------+-----+
# only showing top 20 rows
#
# </div>

# %%
artists_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[36]: 9451</div>

# %%
artists_df = song_artists_df.groupBy("a_id").count()
artists_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#                 a_id|count|
# +--------------------+-----+
# 5ty08GXpCMviM7BKW...|    1|
# 6eZxwKfQWK4d5sLOl...|    1|
# 2BNVHk103mhpIy5yt...|    3|
# 0xm9QC55B3ID2zJHj...|    6|
# 6MmRTVIPIe35OsFqW...|    2|
# 5nqTBNYQhCac1II4C...|    2|
# 5T0j6On1EthT2QVNX...|    2|
# 2sN4fSzAm2rAL0HIu...|    4|
# 6kACVPfCOnqzgfEF5...|    2|
# 1EZhPZUiU6c52gOAZ...|    1|
# 4zaslnpNr10iUFJGx...|    8|
# 0dK1wy5v9DDEnhndv...|    1|
# 6HhnhnxLsowYuuejv...|   16|
# 7KHHYdr41rIO5k4EN...|    1|
# 4qsJVo9DrBRnCzp3i...|    3|
# 5AqhBC5pt6b0WVpUA...|    1|
# 4FC10Nffya2LWWVBf...|    1|
# 6dKYo2aegt1Cpez6t...|    1|
# 3UwlejyX2b458azZ7...|    2|
# 4StKCngkSnvEqzfbi...|    9|
# +--------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
artists_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: 9532</div>
